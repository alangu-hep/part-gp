# %%
import os
import sys
from pathlib import Path
import glob
PATH_TO_PARTGP = os.getenv("PATH_TO_PARTGP")
sys.path.append(os.path.abspath(PATH_TO_PARTGP))

import numpy
import matplotlib.pyplot as plt
import torch
import torch.nn as nn
import uproot

from weaver.nn.model.ParticleTransformer import ParticleTransformer
from weaver.utils.import_tools import import_module
from weaver.utils.dataset import SimpleIterDataset
from weaver.train import test_load
from weaver.utils.nn.tools import evaluate_classification

from utils.nn_utils.hook_handler import register_forward_hooks, remove_all_forward_hooks

# %%
device = torch.device("cuda" if torch.cuda.is_available() else "cpu")
training = False
load_model = True
datasets_path = os.getenv("PART_DATA")

# %%
# Arguments for weaver
class Args:
    def __init__(self, **kwargs):
        # defaults
        self.data_test = []
        self.num_workers = 0
        self.data_config = ''
        self.extra_test_selection = None
        self.data_fraction = 0
        self.batch_size = 0
        
        for key, value in kwargs.items():
            setattr(self, key, value)

# %%
# Set up paths

data_types = ['full', 'kinpid', 'kin']

weight_paths = {
    'full': 'part_models/ParT_full.pt',
    'kinpid': 'part_models/ParT_kinpid.pt',
    'kin': 'part_models/ParT_kin.pt'
}

config_paths = {
    'full': 'data_config/JetClass/JetClass_full.yaml',
    'kinpid': 'data_config/JetClass/JetClass_kinpid.yaml',
    'kin': 'data_config/JetClass/JetClass_kin.yaml'
}

jetclass_data = {
    'train': 'JetClass/Pythia/train_100M',
    'validation': 'JetClass/Pythia/val_5M',
    'test': 'JetClass/Pythia/test_20M'
}

# %%
path_to_network = (Path(PATH_TO_PARTGP) / 'part_models/ParticleTransformer.py')

network_module = import_module(path_to_network, name='_network_module')

# %%
def initialize_models(types, weights, configs):

    models = {}

    for t in types:
        
        # Initialize Model Template

        config_path = (Path(PATH_TO_PARTGP) / configs[t])
        data_config = SimpleIterDataset({}, str(config_path), for_training=training).config
        model, model_info = network_module.get_model(data_config)
    
        # Load Weights
        if load_model:
            weights_path = (Path(PATH_TO_PARTGP) / weights[t])
            wts = torch.load(str(weights_path), map_location = device, weights_only = True)
            model.load_state_dict(wts)
            
        # Let's organize the model and extra info
        models[t] = {
            'model': model,
            'info': model_info,
            'loss': network_module.get_loss(data_config)
        }
        
    return models

models = initialize_models(data_types, weight_paths, config_paths)

# %%
full = models['full']['model']

part_full = full.to(device)

# %%
model = part_full

# %%
for name, module in model.named_modules():
    print(name)
# Out:
# mod
# mod.trimmer
# mod.embed
# mod.embed.input_bn
# mod.embed.embed
# mod.embed.embed.0
# mod.embed.embed.1
# mod.embed.embed.2
# mod.embed.embed.3
# mod.embed.embed.4
# mod.embed.embed.5
# mod.embed.embed.6
# mod.embed.embed.7
# mod.embed.embed.8
# mod.pair_embed
# mod.pair_embed.embed
# mod.pair_embed.embed.0
# mod.pair_embed.embed.1
# mod.pair_embed.embed.2
# mod.pair_embed.embed.3
# mod.pair_embed.embed.4
# mod.pair_embed.embed.5
# mod.pair_embed.embed.6
# mod.pair_embed.embed.7
# mod.pair_embed.embed.8
# mod.pair_embed.embed.9
# mod.pair_embed.embed.10
# mod.pair_embed.embed.11
# mod.pair_embed.embed.12
# mod.blocks
# mod.blocks.0
# mod.blocks.0.pre_attn_norm
# mod.blocks.0.attn
# mod.blocks.0.attn.out_proj
# mod.blocks.0.post_attn_norm
# mod.blocks.0.dropout
# mod.blocks.0.pre_fc_norm
# mod.blocks.0.fc1
# mod.blocks.0.act
# mod.blocks.0.act_dropout
# mod.blocks.0.post_fc_norm
# mod.blocks.0.fc2
# mod.blocks.1
# mod.blocks.1.pre_attn_norm
# mod.blocks.1.attn
# mod.blocks.1.attn.out_proj
# mod.blocks.1.post_attn_norm
# mod.blocks.1.dropout
# mod.blocks.1.pre_fc_norm
# mod.blocks.1.fc1
# mod.blocks.1.act
# mod.blocks.1.act_dropout
# mod.blocks.1.post_fc_norm
# mod.blocks.1.fc2
# mod.blocks.2
# mod.blocks.2.pre_attn_norm
# mod.blocks.2.attn
# mod.blocks.2.attn.out_proj
# mod.blocks.2.post_attn_norm
# mod.blocks.2.dropout
# mod.blocks.2.pre_fc_norm
# mod.blocks.2.fc1
# mod.blocks.2.act
# mod.blocks.2.act_dropout
# mod.blocks.2.post_fc_norm
# mod.blocks.2.fc2
# mod.blocks.3
# mod.blocks.3.pre_attn_norm
# mod.blocks.3.attn
# mod.blocks.3.attn.out_proj
# mod.blocks.3.post_attn_norm
# mod.blocks.3.dropout
# mod.blocks.3.pre_fc_norm
# mod.blocks.3.fc1
# mod.blocks.3.act
# mod.blocks.3.act_dropout
# mod.blocks.3.post_fc_norm
# mod.blocks.3.fc2
# mod.blocks.4
# mod.blocks.4.pre_attn_norm
# mod.blocks.4.attn
# mod.blocks.4.attn.out_proj
# mod.blocks.4.post_attn_norm
# mod.blocks.4.dropout
# mod.blocks.4.pre_fc_norm
# mod.blocks.4.fc1
# mod.blocks.4.act
# mod.blocks.4.act_dropout
# mod.blocks.4.post_fc_norm
# mod.blocks.4.fc2
# mod.blocks.5
# mod.blocks.5.pre_attn_norm
# mod.blocks.5.attn
# mod.blocks.5.attn.out_proj
# mod.blocks.5.post_attn_norm
# mod.blocks.5.dropout
# mod.blocks.5.pre_fc_norm
# mod.blocks.5.fc1
# mod.blocks.5.act
# mod.blocks.5.act_dropout
# mod.blocks.5.post_fc_norm
# mod.blocks.5.fc2
# mod.blocks.6
# mod.blocks.6.pre_attn_norm
# mod.blocks.6.attn
# mod.blocks.6.attn.out_proj
# mod.blocks.6.post_attn_norm
# mod.blocks.6.dropout
# mod.blocks.6.pre_fc_norm
# mod.blocks.6.fc1
# mod.blocks.6.act
# mod.blocks.6.act_dropout
# mod.blocks.6.post_fc_norm
# mod.blocks.6.fc2
# mod.blocks.7
# mod.blocks.7.pre_attn_norm
# mod.blocks.7.attn
# mod.blocks.7.attn.out_proj
# mod.blocks.7.post_attn_norm
# mod.blocks.7.dropout
# mod.blocks.7.pre_fc_norm
# mod.blocks.7.fc1
# mod.blocks.7.act
# mod.blocks.7.act_dropout
# mod.blocks.7.post_fc_norm
# mod.blocks.7.fc2
# mod.cls_blocks
# mod.cls_blocks.0
# mod.cls_blocks.0.pre_attn_norm
# mod.cls_blocks.0.attn
# mod.cls_blocks.0.attn.out_proj
# mod.cls_blocks.0.post_attn_norm
# mod.cls_blocks.0.dropout
# mod.cls_blocks.0.pre_fc_norm
# mod.cls_blocks.0.fc1
# mod.cls_blocks.0.act
# mod.cls_blocks.0.act_dropout
# mod.cls_blocks.0.post_fc_norm
# mod.cls_blocks.0.fc2
# mod.cls_blocks.1
# mod.cls_blocks.1.pre_attn_norm
# mod.cls_blocks.1.attn
# mod.cls_blocks.1.attn.out_proj
# mod.cls_blocks.1.post_attn_norm
# mod.cls_blocks.1.dropout
# mod.cls_blocks.1.pre_fc_norm
# mod.cls_blocks.1.fc1
# mod.cls_blocks.1.act
# mod.cls_blocks.1.act_dropout
# mod.cls_blocks.1.post_fc_norm
# mod.cls_blocks.1.fc2
# mod.norm
# mod.fc
# mod.fc.0

# %%
interesting_layers = {
    'post_layer_embed': model.mod.embed.embed,
    'post_pair_embed': model.mod.pair_embed.embed,
    'first_layer_attn': model.mod.blocks[0].attn,
    'first_layer_block': model.mod.blocks[0],
    'final_layer_attn': model.mod.blocks[7].attn,
    'final_layer_block': model.mod.blocks[7],
    'first_cls_attn': model.mod.cls_blocks[0].attn,
    'first_cls_block': model.mod.cls_blocks[0],
    'final_cls_attn': model.mod.cls_blocks[1].attn,
    'final_cls_block': model.mod.cls_blocks[1],
    'final_logits': model.mod.fc
}

# %%
outputs = {name: [] for name in interesting_layers.keys()}

# Safety Precaution

remove_all_forward_hooks(model)

handles = register_forward_hooks(location_dict=interesting_layers, outputs=outputs)
# Out:
# Removing all hooks within the model
# Forward Hook Registered: post_layer_embed
# Forward Hook Registered: post_pair_embed
# Forward Hook Registered: first_layer_attn
# Forward Hook Registered: first_layer_block
# Forward Hook Registered: final_layer_attn
# Forward Hook Registered: final_layer_block
# Forward Hook Registered: first_cls_attn
# Forward Hook Registered: first_cls_block
# Forward Hook Registered: final_cls_attn
# Forward Hook Registered: final_cls_block
# Forward Hook Registered: final_logits

# %%
# Check to see if hooks exist

print(interesting_layers['final_logits']._forward_hooks)
print(handles['final_logits'])
# Out:
# OrderedDict([(10, <function save_outputs.<locals>.hook at 0x7c53f37c04c0>)])
# <torch.utils.hooks.RemovableHandle object at 0x7c53f5149630>

# %%
# Paths

training_set = str(Path(datasets_path) / jetclass_data['train'])
demo_files = glob.glob(training_set + '/*_000.root')
config_path = str(Path(PATH_TO_PARTGP) / config_paths['full'])

# Set arguments
args = Args(data_test = demo_files, data_config = config_path, data_fraction = 0.005, batch_size = 32) # Run an incredibly small demo

test_loaders, data_config = test_load(args)

for name, get_test_loader in test_loaders.items():
    
    test_loader = get_test_loader()
    
    test_metric, scores, labels, observers = evaluate_classification(model, test_loader, device, epoch=None, for_training=False)
    
    del test_loader
# Out:
# 0it [00:00, ?it/s]
# === Restarting DataIter test_, seed=None ===
# /home/alang/anaconda3/envs/ParT/lib/python3.10/site-packages/torch/nn/functional.py:6044: UserWarning: Support for mismatched key_padding_mask and attn_mask is deprecated. Use same type for both instead.
#   warnings.warn(
# /home/alang/anaconda3/envs/ParT/lib/python3.10/site-packages/torch/nn/functional.py:6044: UserWarning: Support for mismatched key_padding_mask and attn_mask is deprecated. Use same type for both instead.
#   warnings.warn(
# 157it [00:11, 14.03it/s, Loss=0.00000, AvgLoss=0.00000, Acc=0.75000, AvgAcc=0.85840]

# %%
observers['jet_pt']
# Out:
# <Array [856, 545, 537, 640, 590, ..., 601, 686, 823, 896] type='5000 * float32'>

# %%
# Iteration 1 Outputs

print(outputs['final_logits'][0])
# Out:
# tensor([[ 1.2881,  8.6138, -1.9069,  1.8779, -4.5168, -8.0102,  3.4128, -5.4139,
#          -3.9643, -5.0155],
#         [-0.2050,  1.2807, -0.5661, -1.1434, -2.0372, -0.8013,  1.1555,  2.0963,
#          -1.2802, -0.7061],
#         [-0.8722,  2.5090,  2.1592,  4.2234,  2.8238, -1.4500, -1.9209, -3.1409,
#          -3.4871, -2.6612],
#         [ 3.8417, 10.3349, -0.9703, -0.8127, -5.9063, -6.3644,  2.8431, -6.6620,
#          -1.7865, -0.4859],
#         [ 2.4278, 11.6852, -2.4629,  0.4811, -6.8531, -8.7825,  4.4419, -6.4352,
#          -3.9579, -2.8979],
#         [ 1.3520,  6.2128, -1.4011, -0.6865, -0.1083, -6.2026,  0.9606, -3.0825,
#           1.5226, -2.0052],
#         [-0.3114,  8.2566, -4.1326, -2.0885, -8.8568, -5.1508,  7.9680, -3.0312,
#          -6.3298, -3.8241],
#         [-0.2341,  8.4554, -1.9621,  4.0125, -1.8350, -9.6541,  2.4948, -6.2103,
#          -2.1334, -5.1094],
#         [ 2.9507,  8.2878, -3.2807,  4.1379, -5.9809, -8.4298,  2.9307, -5.4795,
#          -2.6054, -2.4350],
#         [-0.5854,  3.6881,  3.2292,  3.1031,  2.6639, -5.8614, -2.5926, -3.2096,
#           0.8594, -4.1047],
#         [ 0.1441,  9.9344, -0.7365,  1.3730, -3.8729, -9.4056,  2.8715, -6.1892,
#          -0.3432, -4.7077],
#         [ 0.3182,  9.6568, -1.3724,  0.9925, -6.5347, -7.6499,  4.0634, -4.5719,
#          -3.5547, -3.9603],
#         [-1.3799,  8.8789,  4.3502, -1.5169, -6.9798, -6.4784,  2.5855, -4.2061,
#          -1.5273, -5.7178],
#         [ 1.1367,  7.4427, -2.6043,  0.2601, -4.6876, -8.8807,  4.3933, -4.9386,
#          -1.2151, -4.1501],
#         [ 1.4382,  9.5363, -2.0796, -1.1055, -5.5085, -6.8120,  3.6923, -3.6453,
#          -2.3297, -2.2095],
#         [ 0.5392,  7.1923, -1.6288,  2.7290, -2.9525, -8.1575,  1.6689, -4.1633,
#           1.2088, -3.6718],
#         [ 0.8580,  8.8625, -2.5255,  2.5029, -4.6249, -9.4949,  4.0559, -5.5850,
#          -4.4345, -4.9183],
#         [ 2.3500, 12.0290, -2.5963,  0.9174, -7.3638, -8.4140,  4.7418, -6.7578,
#          -4.7767, -3.0374],
#         [-1.5538,  5.9265, -1.0584,  0.6392,  2.0472, -9.1211,  2.1880, -4.6496,
#          -0.5590, -6.7823],
#         [-0.5439,  9.0162, -1.9163,  4.7777, -3.9360, -8.4214,  2.6857, -5.5152,
#          -2.6797, -4.9622],
#         [-0.2224,  9.4116, -2.3355,  4.9068, -5.0027, -8.1539,  3.3125, -5.4457,
#          -4.7395, -4.8559],
#         [ 3.6071,  9.5355, -2.2450, -0.2481, -6.1399, -7.4248,  2.7153, -5.1721,
#           2.1888, -1.8116],
#         [ 0.6121, 11.9200, -1.7688,  1.2787, -6.3725, -8.5717,  4.8084, -6.9854,
#          -5.2821, -4.8487],
#         [ 1.5944,  6.1317, -3.3201,  0.4753, -4.4145, -7.7281,  4.3014, -4.6163,
#          -1.1532, -1.2017],
#         [ 3.4367, 11.3986, -2.1888, -0.0213, -7.2218, -8.2007,  4.2318, -6.5575,
#          -4.0601, -2.1793],
#         [ 1.5342,  9.4039, -1.3844,  1.0914, -5.7077, -9.0726,  3.5329, -5.5099,
#          -2.5925, -3.3666],
#         [-0.0514,  4.8013, -4.2283, -1.4635, -3.7257, -6.8254,  5.0586, -1.9153,
#           1.4070, -5.7401],
#         [-2.4525,  6.9819,  3.4892,  1.6393, -1.1618, -7.3614,  0.7736, -3.7395,
#          -4.4882, -5.7928],
#         [-0.0934,  9.0904, -2.2925,  0.4331, -3.7835, -8.3074,  4.2940, -5.7906,
#          -1.7384, -3.9000],
#         [-0.2314,  8.8373,  1.3127,  0.2009, -5.2710, -7.2012,  2.6503, -4.2081,
#          -3.3857, -4.2179],
#         [ 1.0151,  8.1008, -0.9786,  1.5183, -5.0935, -7.7418,  2.6777, -3.8660,
#          -2.7149, -4.2097],
#         [ 2.6400,  7.2003, -2.0024, -0.2828, -4.0940, -6.8347,  1.9949, -3.9344,
#           3.4656, -0.2508]], device='cuda:0')
